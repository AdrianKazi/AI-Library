# %% [markdown]
# # Tokenizing

# %%
dir(encoding)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_core_bpe',
#  '_encode_bytes',
#  '_encode_only_native_bpe',
#  '_encode_single_piece',
#  '_mergeable_ranks',
#  '_pat_str',
#  '_special_token_values',
#  '_special_tokens',
#  'decode',
#  'decode_batch',
#  'decode_bytes',
#  'decode_bytes_batch',
#  'decode_single_token_bytes',
#  'decode_tokens_bytes',
#  'decode_with_offsets',
#  'encode',
#  'encode_batch',
#  'encode_ordinary',
#  'encode_ordinary_batch',
#  'encode_single_token',
#  'encode_to_numpy',
#  'encode_with_unstable',
#  'eot_token',
#  'is_special_token',
# ...

# %%
import tiktoken

encoding = tiktoken.encoding_for_model('gpt-4.1-mini')

tokens = encoding.encode('Hi my name is Ed')
tokens
# Out:
# [12194, 922, 1308, 382, 6117]

# %%
for token_id in tokens:
  token_text = encoding.decode([token_id])
  print(f'{token_id} = {token_text}')
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 6117 =  Ed

# %%
encoding.decode([326])
# Out:
# ' and'

# %% [markdown]
# # Illusion of Memory

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = "..."

if not api_key:
  print('No API')
elif not api_key.startswith('sk-proj-'):
  print('An API key was found, but it doesn\'t start sk-proj-; please check you\'re using right key')
else:
  print('API key found')
# Out:
# API key found

# %%
# !pip install openai -q

import os
from openai import OpenAI
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = api_key

openai = OpenAI()

# %% [markdown]
# A message to OpenAI is a list of dicts

# %%
messages = [
    {'role':'system', "content":"You are a helpful assistant"},
    {'role':'user',   "content":"What's my name?"}
]
messages
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant'},
#  {'role': 'user', 'content': "What's my name?"}]

# %%
response = openai.chat.completions.create(model = 'gpt-4.1-mini', messages = messages)
response.choices[0].message.content
# Out:
# 'I’m not sure what your name is based on our current conversation. Could you please tell me your name?'

# %%
messages = [
    {'role':'system', "content":"You are a helpful assistant"},
    {'role':'user',   "content":"Hi Im Adrian?"},
    {'role':'assistant', "content":"Hi Adrian how can I assist you"},
    {'role':'user',   "content":"What's my name?"},
]

# %%
response = openai.chat.completions.create(model = 'gpt-4.1-mini', messages=messages)
response.choices[0].message.content
# Out:
# 'Your name is Adrian. How can I help you today?'
